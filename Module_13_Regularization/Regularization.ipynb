# %% [markdown]
# <a href="https://colab.research.google.com/github/annika-sachdeva/braintumorclassification/blob/main/Module_13_Regularization/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Objective
# * To acquaint you with the problem of overfit models and to mitigate it with regularization

# %%
# Basic packages
import pandas as pd
import numpy as np
import re
import collections
import matplotlib.pyplot as plt
from pathlib import Path

# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('stopwords')

# Packages for modeling
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

NB_WORDS = 10000  # Parameter indicating the number of words we'll put in the dictionary
NB_START_EPOCHS = 20  # Number of epochs we usually start to train with
BATCH_SIZE = 512  # Size of the batches used in the mini-batch gradient descent
MAX_LEN = 20  # Maximum number of words in a sequence

root = Path('../content/')
input_path = root / 'input/'
ouput_path = root / 'output/'
source_path = root / 'source/'

def deep_model(model, X_train, y_train, X_valid, y_valid):
    model.compile(optimizer='rmsprop'
                  , loss='categorical_crossentropy'
                  , metrics=['accuracy'])

    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=1)
    return history

def eval_metric(model, history, metric_name):
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]

    e = range(1, NB_START_EPOCHS + 1)

    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    plt.show()

def remove_stopwords(input_text):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["n't", "not", "no"]
    words = input_text.split()
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1]
    return " ".join(clean_words)

def remove_mentions(input_text):
    return re.sub(r'@\w+', '', input_text)

def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
    model.fit(X_train
              , y_train
              , epochs=epoch_stop
              , batch_size=BATCH_SIZE
              , verbose=1)
    results = model.evaluate(X_test, y_test)
    print()
    print('Test accuracy: {0:.2f}%'.format(results[1]*100))
    return results

def compare_models_by_metric(model_1, model_2, model_hist_1, model_hist_2, metric):
    metric_model_1 = model_hist_1.history[metric]
    metric_model_2 = model_hist_2.history[metric]

    e = range(1, NB_START_EPOCHS + 1)

    metrics_dict = {
        'acc' : 'Training Accuracy',
        'loss' : 'Training Loss',
        'val_acc' : 'Validation accuracy',
        'val_loss' : 'Validation loss'
    }

    metric_label = metrics_dict[metric]

    plt.plot(e, metric_model_1, 'bo', label=model_1.name)
    plt.plot(e, metric_model_2, 'b', label=model_2.name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_label)
    plt.title('Comparing ' + metric_label + ' between models')
    plt.legend()
    plt.show()

def optimal_epoch(model_hist):
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    print("Minimum validation loss reached in epoch {}".format(min_epoch))
    return min_epoch

! gdown --id 1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
! mkdir input/
! mv Tweets.csv input/

df = pd.read_csv(input_path / 'Tweets.csv')
df = df.reindex(np.random.permutation(df.index))
df = df[['text', 'airline_sentiment']]
df.text = df.text.apply(remove_stopwords).apply(remove_mentions)

X_train, X_test, y_train, y_test = train_test_split(df.text, df.airline_sentiment, test_size=0.1, random_state=37)

tk = Tokenizer(num_words=NB_WORDS,
               filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n',
               lower=True,
               char_level=False,
               split=' ')
tk.fit_on_texts(X_train)

X_train_oh = tk.texts_to_matrix(X_train, mode='binary')
X_test_oh = tk.texts_to_matrix(X_test, mode='binary')

le = LabelEncoder()
y_train_le = le.fit_transform(y_train)
y_test_le = le.transform(y_test)
y_train_oh = to_categorical(y_train_le)
y_test_oh = to_categorical(y_test_le)

X_train_rest, X_valid, y_train_rest, y_valid = train_test_split(X_train_oh, y_train_oh, test_size=0.1, random_state=37)

base_model = models.Sequential()
base_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(3, activation='softmax'))
base_history = deep_model(base_model, X_train_rest, y_train_rest, X_valid, y_valid)
base_min = optimal_epoch(base_history)

reduced_model = models.Sequential()
reduced_model.add(layers.Dense(16, activation='relu', input_shape=(NB_WORDS,)))
reduced_model.add(layers.Dense(3, activation='softmax'))
reduced_history = deep_model(reduced_model, X_train_rest, y_train_rest, X_valid, y_valid)
reduced_min = optimal_epoch(reduced_history)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
# To: /content/Tweets.csv
# 100% 3.42M/3.42M [00:00<00:00, 36.6MB/s]
# Epoch 1/20
# 24/24 [==============================] - 2s 66ms/step - loss: 0.8657 - accuracy: 0.6219 - val_loss: 0.7214 - val_accuracy: 0.6616
# Epoch 2/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6398 - accuracy: 0.7271 - val_loss: 0.5909 - val_accuracy: 0.7769
# Epoch 3/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.4924 - accuracy: 0.8243 - val_loss: 0.5344 - val_accuracy: 0.7989
# Epoch 4/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.3985 - accuracy: 0.8581 - val_loss: 0.5201 - val_accuracy: 0.8012
# Epoch 5/20
# 24/24 [==============================] - 1s 44ms/step - loss: 0.3348 - accuracy: 0.8801 - val_loss: 0.5265 - val_accuracy: 0.7929
# Epoch 6/20
# 24/24 [==============================] - 2s 75ms/step - loss: 0.2869 - accuracy: 0.8992 - val_loss: 0.5487 - val_accuracy: 0.7800
# Epoch 7/20
# 24/24 [==============================] - 2s 78ms/step - loss: 0.2475 - accuracy: 0.9134 - val_loss: 0.5744 - val_accuracy: 0.7853
# Epoch 8/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.2139 - accuracy: 0.9269 - val_loss: 0.6129 - val_accuracy: 0.7693
# Epoch 9/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.1853 - accuracy: 0.9386 - val_loss: 0.6320 - val_accuracy: 0.7830
# Epoch 10/20
# 24/24 [==============================] - 1s 44ms/step - loss: 0.1610 - accuracy: 0.9470 - val_loss: 0.6752 - val_accuracy: 0.7762
# Epoch 11/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.1398 - accuracy: 0.9561 - val_loss: 0.7124 - val_accuracy: 0.7686
# Epoch 12/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.1225 - accuracy: 0.9615 - val_loss: 0.8012 - val_accuracy: 0.7489
# Epoch 13/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.1086 - accuracy: 0.9655 - val_loss: 0.7958 - val_accuracy: 0.7716
# Epoch 14/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.0943 - accuracy: 0.9707 - val_loss: 0.8401 - val_accuracy: 0.7739
# Epoch 15/20
# 24/24 [==============================] - 1s 44ms/step - loss: 0.0839 - accuracy: 0.9742 - val_loss: 0.8852 - val_accuracy: 0.7602
# Epoch 16/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0744 - accuracy: 0.9777 - val_loss: 0.9225 - val_accuracy: 0.7618
# Epoch 17/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0665 - accuracy: 0.9803 - val_loss: 0.9674 - val_accuracy: 0.7663
# Epoch 18/20
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0590 - accuracy: 0.9830 - val_loss: 1.0268 - val_accuracy: 0.7511
# Epoch 19/20
# 24/24 [==============================] - 3s 105ms/step - loss: 0.0530 - accuracy: 0.9845 - val_loss: 1.0600 - val_accuracy: 0.7496
# Epoch 20/20
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0485 - accuracy: 0.9856 - val_loss: 1.0892 - val_accuracy: 0.7656
# Minimum validation loss reached in epoch 4
# Epoch 1/20
# 24/24 [==============================] - 1s 39ms/step - loss: 1.0301 - accuracy: 0.6169 - val_loss: 0.9537 - val_accuracy: 0.6624
# Epoch 2/20
# 24/24 [==============================] - 1s 27ms/step - loss: 0.8921 - accuracy: 0.6740 - val_loss: 0.8354 - val_accuracy: 0.6821
# Epoch 3/20
# 24/24 [==============================] - 1s 28ms/step - loss: 0.7790 - accuracy: 0.6962 - val_loss: 0.7458 - val_accuracy: 0.6920
# Epoch 4/20
# 24/24 [==============================] - 1s 26ms/step - loss: 0.6934 - accuracy: 0.7185 - val_loss: 0.6845 - val_accuracy: 0.7178
# Epoch 5/20
# 24/24 [==============================] - 1s 26ms/step - loss: 0.6287 - accuracy: 0.7516 - val_loss: 0.6406 - val_accuracy: 0.7420
# Epoch 6/20
# 24/24 [==============================] - 1s 26ms/step - loss: 0.5765 - accuracy: 0.7835 - val_loss: 0.6066 - val_accuracy: 0.7618
# Epoch 7/20
# 24/24 [==============================] - 1s 27ms/step - loss: 0.5327 - accuracy: 0.8132 - val_loss: 0.5810 - val_accuracy: 0.7769
# Epoch 8/20
# 24/24 [==============================] - 1s 26ms/step - loss: 0.4953 - accuracy: 0.8329 - val_loss: 0.5607 - val_accuracy: 0.7838
# Epoch 9/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.4641 - accuracy: 0.8466 - val_loss: 0.5463 - val_accuracy: 0.7868
# Epoch 10/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.4371 - accuracy: 0.8550 - val_loss: 0.5353 - val_accuracy: 0.7936
# Epoch 11/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.4139 - accuracy: 0.8630 - val_loss: 0.5273 - val_accuracy: 0.7944
# Epoch 12/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.3932 - accuracy: 0.8690 - val_loss: 0.5218 - val_accuracy: 0.7959
# Epoch 13/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.3747 - accuracy: 0.8733 - val_loss: 0.5180 - val_accuracy: 0.8005
# Epoch 14/20
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3582 - accuracy: 0.8795 - val_loss: 0.5168 - val_accuracy: 0.7989
# Epoch 15/20
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3432 - accuracy: 0.8851 - val_loss: 0.5161 - val_accuracy: 0.7982
# Epoch 16/20
# 24/24 [==============================] - 1s 28ms/step - loss: 0.3290 - accuracy: 0.8897 - val_loss: 0.5164 - val_accuracy: 0.7989
# Epoch 17/20
# 24/24 [==============================] - 1s 26ms/step - loss: 0.3162 - accuracy: 0.8928 - val_loss: 0.5186 - val_accuracy: 0.7997
# Epoch 18/20
# 24/24 [==============================] - 1s 24ms/step - loss: 0.3042 - accuracy: 0.8973 - val_loss: 0.5203 - val_accuracy: 0.7982
# Epoch 19/20
# 24/24 [==============================] - 1s 27ms/step - loss: 0.2932 - accuracy: 0.8997 - val_loss: 0.5237 - val_accuracy: 0.7982
# Epoch 20/20
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2825 - accuracy: 0.9039 - val_loss: 0.5266 - val_accuracy: 0.7997
# Minimum validation loss reached in epoch 15

# %% [markdown]
# # Applying regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights-one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
reg_model = models.Sequential()
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(NB_WORDS,)))
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
reg_model.add(layers.Dense(3, activation='softmax'))
reg_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                640064
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 644419 (2.46 MB)
# Trainable params: 644419 (2.46 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
reg_history = deep_model(reg_model, X_train_rest, y_train_rest, X_valid, y_valid)
reg_min = optimal_epoch(reg_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 59ms/step - loss: 1.0904 - accuracy: 0.6073 - val_loss: 0.9105 - val_accuracy: 0.6555
# Epoch 2/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.8177 - accuracy: 0.7107 - val_loss: 0.7417 - val_accuracy: 0.7625
# Epoch 3/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.6542 - accuracy: 0.8068 - val_loss: 0.6671 - val_accuracy: 0.7860
# Epoch 4/20
# 24/24 [==============================] - 2s 81ms/step - loss: 0.5568 - accuracy: 0.8453 - val_loss: 0.6413 - val_accuracy: 0.7997
# Epoch 5/20
# 24/24 [==============================] - 2s 77ms/step - loss: 0.4950 - accuracy: 0.8637 - val_loss: 0.6388 - val_accuracy: 0.7989
# Epoch 6/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.4487 - accuracy: 0.8803 - val_loss: 0.6421 - val_accuracy: 0.7868
# Epoch 7/20
# 24/24 [==============================] - 1s 44ms/step - loss: 0.4126 - accuracy: 0.8941 - val_loss: 0.6723 - val_accuracy: 0.7701
# Epoch 8/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.3846 - accuracy: 0.9049 - val_loss: 0.6772 - val_accuracy: 0.7709
# Epoch 9/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.3610 - accuracy: 0.9164 - val_loss: 0.6881 - val_accuracy: 0.7898
# Epoch 10/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.3395 - accuracy: 0.9238 - val_loss: 0.7004 - val_accuracy: 0.7853
# Epoch 11/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.3213 - accuracy: 0.9314 - val_loss: 0.7196 - val_accuracy: 0.7716
# Epoch 12/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.3055 - accuracy: 0.9372 - val_loss: 0.7476 - val_accuracy: 0.7633
# Epoch 13/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.2924 - accuracy: 0.9417 - val_loss: 0.7503 - val_accuracy: 0.7678
# Epoch 14/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.2816 - accuracy: 0.9482 - val_loss: 0.7638 - val_accuracy: 0.7671
# Epoch 15/20
# 24/24 [==============================] - 2s 102ms/step - loss: 0.2698 - accuracy: 0.9531 - val_loss: 0.7855 - val_accuracy: 0.7716
# Epoch 16/20
# 24/24 [==============================] - 3s 105ms/step - loss: 0.2608 - accuracy: 0.9561 - val_loss: 0.8040 - val_accuracy: 0.7648
# Epoch 17/20
# 24/24 [==============================] - 1s 44ms/step - loss: 0.2521 - accuracy: 0.9588 - val_loss: 0.8388 - val_accuracy: 0.7481
# Epoch 18/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.2435 - accuracy: 0.9616 - val_loss: 0.8292 - val_accuracy: 0.7625
# Epoch 19/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.2360 - accuracy: 0.9653 - val_loss: 0.8202 - val_accuracy: 0.7716
# Epoch 20/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.2291 - accuracy: 0.9668 - val_loss: 0.8396 - val_accuracy: 0.7693
# Minimum validation loss reached in epoch 5

# %% [markdown]
# For the regularized model we notice that it starts overfitting in the same epoch as the baseline model. However, the loss increases much slower afterwards.

# %%
eval_metric(reg_model, reg_history, 'loss')

# %%
compare_models_by_metric(base_model, reg_model, base_history, reg_history, 'val_loss')

# %% [markdown]
# ## Question 1
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 1

# %%
weights = [-5, 4, -3, 2, 1]

def l1_norm(weights):
    reg = sum(abs(w) for w in weights)
    return reg

print(l1_norm(weights))
# Out:
# 15

# %% [markdown]
# ## Question 2
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||_2^2$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 2

# %%
weights = [-5, 4, -3, 2, 1]

def l2_norm(weights):
    reg = sum(w**2 for w in weights)
    return reg

print(l2_norm(weights))
# Out:
# 55

# %% [markdown]
# ## Adding dropout layers
# Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our network to see how well they do at reducing overfitting:

# %%
drop_model = models.Sequential()
drop_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(64, activation='relu'))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(3, activation='softmax'))
drop_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                640064
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644419 (2.46 MB)
# Trainable params: 644419 (2.46 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
drop_history = deep_model(drop_model, X_train_rest, y_train_rest, X_valid, y_valid)
drop_min = optimal_epoch(drop_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 3s 86ms/step - loss: 0.9128 - accuracy: 0.6028 - val_loss: 0.7583 - val_accuracy: 0.6358
# Epoch 2/20
# 24/24 [==============================] - 2s 80ms/step - loss: 0.7331 - accuracy: 0.6491 - val_loss: 0.6714 - val_accuracy: 0.6995
# Epoch 3/20
# 24/24 [==============================] - 2s 77ms/step - loss: 0.6383 - accuracy: 0.7242 - val_loss: 0.6073 - val_accuracy: 0.7739
# Epoch 4/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.5591 - accuracy: 0.7956 - val_loss: 0.5651 - val_accuracy: 0.7982
# Epoch 5/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.4928 - accuracy: 0.8237 - val_loss: 0.5441 - val_accuracy: 0.8042
# Epoch 6/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.4442 - accuracy: 0.8437 - val_loss: 0.5355 - val_accuracy: 0.7959
# Epoch 7/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.3972 - accuracy: 0.8617 - val_loss: 0.5288 - val_accuracy: 0.7906
# Epoch 8/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.3722 - accuracy: 0.8698 - val_loss: 0.5343 - val_accuracy: 0.7929
# Epoch 9/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.3377 - accuracy: 0.8840 - val_loss: 0.5464 - val_accuracy: 0.7959
# Epoch 10/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.3067 - accuracy: 0.8939 - val_loss: 0.5569 - val_accuracy: 0.8020
# Epoch 11/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.2886 - accuracy: 0.8996 - val_loss: 0.5690 - val_accuracy: 0.7997
# Epoch 12/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.2584 - accuracy: 0.9138 - val_loss: 0.5868 - val_accuracy: 0.7891
# Epoch 13/20
# 24/24 [==============================] - 2s 78ms/step - loss: 0.2382 - accuracy: 0.9190 - val_loss: 0.5968 - val_accuracy: 0.7944
# Epoch 14/20
# 24/24 [==============================] - 2s 75ms/step - loss: 0.2198 - accuracy: 0.9236 - val_loss: 0.6229 - val_accuracy: 0.7921
# Epoch 15/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.2009 - accuracy: 0.9340 - val_loss: 0.6449 - val_accuracy: 0.7974
# Epoch 16/20
# 24/24 [==============================] - 2s 89ms/step - loss: 0.1875 - accuracy: 0.9365 - val_loss: 0.6616 - val_accuracy: 0.7921
# Epoch 17/20
# 24/24 [==============================] - 2s 91ms/step - loss: 0.1776 - accuracy: 0.9410 - val_loss: 0.6872 - val_accuracy: 0.7929
# Epoch 18/20
# 24/24 [==============================] - 2s 93ms/step - loss: 0.1616 - accuracy: 0.9479 - val_loss: 0.7054 - val_accuracy: 0.7898
# Epoch 19/20
# 24/24 [==============================] - 2s 66ms/step - loss: 0.1479 - accuracy: 0.9529 - val_loss: 0.7346 - val_accuracy: 0.7906
# Epoch 20/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.1462 - accuracy: 0.9518 - val_loss: 0.7526 - val_accuracy: 0.7891
# Minimum validation loss reached in epoch 7

# %%
eval_metric(drop_model, drop_history, 'loss')

# %% [markdown]
# The model with dropout layers starts overfitting later than the baseline model. The loss also increases slower than the baseline model.

# %%
compare_models_by_metric(base_model, drop_model, base_history, drop_history, 'val_loss')

# %% [markdown]
# The model with the Dropout layers starts overfitting later. Compared to the baseline model the loss also remains much lower.

# %% [markdown]
# ## Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3)
])

# %%
combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 8s 289ms/step - loss: 1.5300 - accuracy: 0.6130 - val_loss: 1.0347 - val_accuracy: 0.6434
# Epoch 2/20
# 24/24 [==============================] - 8s 356ms/step - loss: 3.1875 - accuracy: 0.6812 - val_loss: 8.6564 - val_accuracy: 0.7178
# Epoch 3/20
# 24/24 [==============================] - 7s 279ms/step - loss: 7.2475 - accuracy: 0.7321 - val_loss: 9.8320 - val_accuracy: 0.7109
# Epoch 4/20
# 24/24 [==============================] - 8s 343ms/step - loss: 7.3173 - accuracy: 0.7522 - val_loss: 4.5254 - val_accuracy: 0.7291
# Epoch 5/20
# 24/24 [==============================] - 7s 278ms/step - loss: 4.7752 - accuracy: 0.7721 - val_loss: 9.6752 - val_accuracy: 0.7466
# Epoch 6/20
# 24/24 [==============================] - 8s 341ms/step - loss: 7.0288 - accuracy: 0.7831 - val_loss: 10.0376 - val_accuracy: 0.7299
# Epoch 7/20
# 24/24 [==============================] - 7s 279ms/step - loss: 7.5040 - accuracy: 0.7667 - val_loss: 10.7614 - val_accuracy: 0.6586
# Epoch 8/20
# 24/24 [==============================] - 8s 339ms/step - loss: 9.6964 - accuracy: 0.6291 - val_loss: 10.5043 - val_accuracy: 0.6351
# Epoch 9/20
# 24/24 [==============================] - 7s 283ms/step - loss: 9.0309 - accuracy: 0.6273 - val_loss: 10.8429 - val_accuracy: 0.6351
# Epoch 10/20
# 24/24 [==============================] - 9s 389ms/step - loss: 5.3707 - accuracy: 0.6377 - val_loss: 2.5677 - val_accuracy: 0.6540
# Epoch 11/20
# 24/24 [==============================] - 8s 348ms/step - loss: 6.2927 - accuracy: 0.6429 - val_loss: 2.5002 - val_accuracy: 0.6593
# Epoch 12/20
# 24/24 [==============================] - 7s 286ms/step - loss: 7.3466 - accuracy: 0.6428 - val_loss: 2.9585 - val_accuracy: 0.6555
# Epoch 13/20
# 24/24 [==============================] - 8s 348ms/step - loss: 8.9210 - accuracy: 0.6375 - val_loss: 13.0659 - val_accuracy: 0.6548
# Epoch 14/20
# 24/24 [==============================] - 7s 279ms/step - loss: 10.1736 - accuracy: 0.6402 - val_loss: 12.8153 - val_accuracy: 0.6571
# Epoch 15/20
# 24/24 [==============================] - 10s 415ms/step - loss: 10.5510 - accuracy: 0.6410 - val_loss: 13.5677 - val_accuracy: 0.6487
# Epoch 16/20
# 24/24 [==============================] - 8s 336ms/step - loss: 10.8935 - accuracy: 0.6387 - val_loss: 13.8067 - val_accuracy: 0.6381
# Epoch 17/20
# 24/24 [==============================] - 8s 323ms/step - loss: 10.4824 - accuracy: 0.6282 - val_loss: 10.4142 - val_accuracy: 0.6351
# Epoch 18/20
# 24/24 [==============================] - 7s 307ms/step - loss: 9.6650 - accuracy: 0.6273 - val_loss: 10.4091 - val_accuracy: 0.6351
# Epoch 19/20
# 24/24 [==============================] - 10s 415ms/step - loss: 9.3255 - accuracy: 0.6273 - val_loss: 10.4284 - val_accuracy: 0.6351
# Epoch 20/20
# 24/24 [==============================] - 8s 349ms/step - loss: 9.0404 - accuracy: 0.6273 - val_loss: 10.5213 - val_accuracy: 0.6351
# Minimum validation loss reached in epoch 1

# %%
eval_metric(combined_model, combined_history, 'loss')

# %%
compare_models_by_metric(base_model, combined_model, base_history, combined_history, 'val_loss')

# %% [markdown]
# ## Question 3
#
# When does it make sense to add both L2 regularization and Dropout?
#
# And what did doing so achieve in this case?

# %% [markdown]
# ### Answer 3
#
# Adding both L2 regularization and Dropout makes sense when dealing with complex models or limited training data to prevent overfitting. L2 regularization penalizes large weights, encouraging the model to keep all weights small. Dropout randomly drops units during training, forcing the model to learn more robust features.

# %% [markdown]
# #Training on the full train data and evaluation on test data
# At first sight the reduced model seems to be the best model for generalization. But let's check that on the test set.

# %%
base_results = test_model(base_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, base_min)
# Out:
# Epoch 1/4
# 26/26 [==============================] - 2s 71ms/step - loss: 0.1470 - accuracy: 0.9639
# Epoch 2/4
# 26/26 [==============================] - 1s 51ms/step - loss: 0.1030 - accuracy: 0.9711
# Epoch 3/4
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0813 - accuracy: 0.9776
# Epoch 4/4
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0663 - accuracy: 0.9815
# 46/46 [==============================] - 0s 4ms/step - loss: 0.9976 - accuracy: 0.7705
#
# Test accuracy: 77.05%

# %%
reduced_results = test_model(reduced_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reduced_min)
# Out:
# Epoch 1/15
# 26/26 [==============================] - 1s 24ms/step - loss: 0.2983 - accuracy: 0.8962
# Epoch 2/15
# 26/26 [==============================] - 1s 32ms/step - loss: 0.2872 - accuracy: 0.9007
# Epoch 3/15
# 26/26 [==============================] - 1s 32ms/step - loss: 0.2770 - accuracy: 0.9049
# Epoch 4/15
# 26/26 [==============================] - 1s 34ms/step - loss: 0.2676 - accuracy: 0.9081
# Epoch 5/15
# 26/26 [==============================] - 1s 33ms/step - loss: 0.2584 - accuracy: 0.9116
# Epoch 6/15
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2499 - accuracy: 0.9158
# Epoch 7/15
# 26/26 [==============================] - 1s 22ms/step - loss: 0.2416 - accuracy: 0.9184
# Epoch 8/15
# 26/26 [==============================] - 1s 23ms/step - loss: 0.2339 - accuracy: 0.9216
# Epoch 9/15
# 26/26 [==============================] - 1s 22ms/step - loss: 0.2267 - accuracy: 0.9259
# Epoch 10/15
# 26/26 [==============================] - 1s 25ms/step - loss: 0.2196 - accuracy: 0.9273
# Epoch 11/15
# 26/26 [==============================] - 1s 22ms/step - loss: 0.2130 - accuracy: 0.9310
# Epoch 12/15
# 26/26 [==============================] - 1s 22ms/step - loss: 0.2067 - accuracy: 0.9343
# Epoch 13/15
# 26/26 [==============================] - 1s 24ms/step - loss: 0.2003 - accuracy: 0.9362
# Epoch 14/15
# 26/26 [==============================] - 1s 22ms/step - loss: 0.1948 - accuracy: 0.9383
# Epoch 15/15
# 26/26 [==============================] - 1s 23ms/step - loss: 0.1891 - accuracy: 0.9399
# 46/46 [==============================] - 0s 2ms/step - loss: 0.5777 - accuracy: 0.8060
#
# Test accuracy: 80.60%

# %%
reg_results = test_model(reg_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reg_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 1s 43ms/step - loss: 0.2892 - accuracy: 0.9463
# Epoch 2/5
# 26/26 [==============================] - 1s 41ms/step - loss: 0.2568 - accuracy: 0.9547
# Epoch 3/5
# 26/26 [==============================] - 1s 51ms/step - loss: 0.2434 - accuracy: 0.9602
# Epoch 4/5
# 26/26 [==============================] - 2s 75ms/step - loss: 0.2326 - accuracy: 0.9642
# Epoch 5/5
# 26/26 [==============================] - 2s 75ms/step - loss: 0.2221 - accuracy: 0.9678
# 46/46 [==============================] - 0s 4ms/step - loss: 0.7909 - accuracy: 0.7917
#
# Test accuracy: 79.17%

# %%
drop_results = test_model(drop_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, drop_min)
# Out:
# Epoch 1/7
# 26/26 [==============================] - 1s 44ms/step - loss: 0.1972 - accuracy: 0.9413
# Epoch 2/7
# 26/26 [==============================] - 1s 43ms/step - loss: 0.1807 - accuracy: 0.9463
# Epoch 3/7
# 26/26 [==============================] - 1s 43ms/step - loss: 0.1640 - accuracy: 0.9498
# Epoch 4/7
# 26/26 [==============================] - 1s 43ms/step - loss: 0.1533 - accuracy: 0.9524
# Epoch 5/7
# 26/26 [==============================] - 1s 44ms/step - loss: 0.1421 - accuracy: 0.9546
# Epoch 6/7
# 26/26 [==============================] - 1s 43ms/step - loss: 0.1314 - accuracy: 0.9577
# Epoch 7/7
# 26/26 [==============================] - 1s 42ms/step - loss: 0.1231 - accuracy: 0.9632
# 46/46 [==============================] - 0s 4ms/step - loss: 0.7946 - accuracy: 0.7964
#
# Test accuracy: 79.64%

# %% [markdown]
# # Handling Underfitting
# * In a general situation, the best strategy is to increase the model complexity by either increasing the number of parameters of your deep learning model or the order of your model. Underfitting is due to the model being simpler than needed. It fails to capture the patterns in the data. Increasing the model complexity will lead to improvement in training performance. If we use a large enough model it can even achieve a training error of zero i.e. the model will memorize the data and suffer from over-fitting. The goal is to hit the optimal sweet spot.
# * Try to train the model for more epochs. Ensure that the loss is decreasing gradually over the course of the training. Otherwise, it is highly likely that there is some kind of bug or problem in the training code/logic itself.
# * If you aren’t shuffling the data after every epoch, it can harm the model performance. Ensuring that you are shuffling the data is a good check to perform at this point.

# %% [markdown]
# #Conclusion
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.
#
# here are the ways to prevent underfitting
#
# * Get more training data.
# * Increase the size or number of parameters in the model.
# * Increase the complexity of the model.
# * Increasing the training time, until cost function is minimised.

# %% [markdown]
# # Bonus content - Visualizing L2 regularization

# %%
import numpy as np
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.debugger import set_trace
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
def plot_contour(f, x1bound, x2bound, resolution, ax):
    x1range = np.linspace(x1bound[0], x1bound[1], resolution)
    x2range = np.linspace(x2bound[0], x2bound[1], resolution)
    xg, yg = np.meshgrid(x1range, x2range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    ax.contour(xg, yg, zg, 100)
    return ax

# %% [markdown]
# Let's create a toy data:

# %%
N = 20
x = np.random.rand(N) * 10
y = -4*x + 10 + 2*np.random.randn(N)

# %% [markdown]
# visualize the regularized **cost function**

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l2_penalty = lambda w: np.dot(w,w)/2
cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l2_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L2 reg. $||w||_2^2$')
plot_contour(cost_plus_l2, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L2 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 1
#
# Plot the same for L1 regularization

# %% [markdown]
# ### Answer

# %%
cost = lambda w: 0.5 * np.mean((w[0] + w[1]*x - y)**2)
l1_penalty = lambda w: np.sum(np.abs(w))
cost_plus_l1 = lambda w: cost(w) + 5 * l1_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||_2^2$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 2
# After looking at the visualization to what the L1 and L2 normalizations, how do they help while training?
#
# L1 regularization helps by producing sparse solutions, effectively performing feature selection and making the model robust to outliers. L2 regularization encourages smaller weights, leading to smoother models with distributed weight contributions, thereby reducing the risk of overfitting.

# %% [markdown]
# # Upload this Colab Notebook to your Github repository. Also add your *reflections* on today's learning in README.md
